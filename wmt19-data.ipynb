# %%
import glob
import gzip
import itertools
import csv
import io
import pickle
import hashlib
import pandas as pd
import numpy as np

# %% [markdown]
# # WMT19 system-level data

# %% [markdown]
# ### Checksums

# %%
mine = '93f6c7fa3ca5d81b1837ccf34c1a80aa'
'./data/'
yours = hashlib.md5(open('data/downloads/wmt19-submitted-data-v3.tgz', 'rb').read()).hexdigest()
print(mine + '\n' + yours)
print(mine == yours)

mine = '8c901c91fde19207cf8494c4af541455'
yours = hashlib.md5(open('data/downloads/wmt19-metrics-task-package.tgz', 'rb').read()).hexdigest()
print(mine + '\n' + yours)
print(mine == yours)

# unzip to data/
# os.system('tar -xvf data/downloads/newstest2017-segment-level-human.tar.gz -p data/')
# os.system('tar -xvf data/downloads/wmt17-metrics-task-package.tgz -p data/')
# Out:
# 93f6c7fa3ca5d81b1837ccf34c1a80aa
# 93f6c7fa3ca5d81b1837ccf34c1a80aa
# True
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e2153640e3f8> in <module>
#       6
#       7 mine = '8c901c91fde19207cf8494c4af541455'
# ----> 8 yours = hashlib.md5(open('data/downloads/wmt19-metrics-task-package.tgz', 'rb').read()).hexdigest()
#       9 print(mine + '\n' + yours)
#      10 print(mine == yours)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/downloads/wmt19-metrics-task-package.tgz'

# %% [markdown]
# ### Official system-level da scores

# %%
da_sys = pd.read_csv('data/wmt19-metrics-task-package/manual-evaluation/DA-syslevel.csv', delimiter=' ')
da_sys.columns = ['lp', 'score', 'system']
da_sys
# Out:
#         lp  score                           system
# 0    en-cs  0.402     CUNI-DocTransformer-T2T.6751
# 1    en-cs  0.401   CUNI-Transformer-T2T-2018.6457
# 2    en-cs  0.388   CUNI-Transformer-T2T-2019.6851
# 3    en-cs  0.223  CUNI-DocTransformer-Marian.6922
# 4    en-cs  0.206                       uedin.6667
# ..     ...    ...                              ...
# 220  de-fr  0.019                       online-Y.0
# 221  de-fr -0.104                  TartuNLP-c.6897
# 222  de-fr -0.194                       online-A.0
# 223  de-fr -0.240                       online-G.0
# 224  de-fr -0.456                       online-X.0
#
# [225 rows x 3 columns]

# %%
sys_scores = pd.DataFrame(data={'lp':[], 'system':[]})

for submission in glob.glob('data/wmt19-metrics-task-package/baselines/*.sys.*'):
    if 'chrF' in submission or 'mteval' in submission:
        continue

    metric_name = submission.split('/')[-1][:-len('.sys.score.gz')]
    print(metric_name)

    hybrid_filtered = '\n'.join(i.replace(' ', '\t') for i in gzip.open(submission, 'rt') if 'hybrid' not in i)
    reader = io.StringIO(hybrid_filtered)
    metric_syss = pd.read_csv(reader, delimiter='\t', header=None)
    
    metric_syss.columns = ['name', 'lp', 'testset', 'system', metric_name] + list(metric_syss.columns[5:])
    
    sys_scores = sys_scores.merge(metric_syss[['lp','system',metric_name]], on=['lp','system'], how='outer')
# Out:
# TER
# CDER
# sacreBLEU-BLEU
# PER
# WER

# %%
# BLEU
metric_name = 'BLEU'
hybrid_filtered = '\n'.join(i.replace(' ', '\t') for i in gzip.open('data/wmt19-metrics-task-package/baselines/mteval-inter.sys.score.gz', 'rt') if 'hybrid' not in i and 'BLEU' in i)
reader = io.StringIO(hybrid_filtered)
metric_syss = pd.read_csv(reader, delimiter='\t', header=None)

metric_syss.columns = ['name', 'lp', 'testset', 'system', metric_name] + list(metric_syss.columns[5:])
sys_scores = sys_scores.merge(metric_syss[['lp','system',metric_name]], on=['lp','system'], how='outer')

# NIST
metric_name = 'NIST'
hybrid_filtered = '\n'.join(i.replace(' ', '\t') for i in gzip.open('data/wmt19-metrics-task-package/baselines/mteval-inter.sys.score.gz', 'rt') if 'hybrid' not in i and 'NIST' in i)
reader = io.StringIO(hybrid_filtered)
metric_syss = pd.read_csv(reader, delimiter='\t', header=None)

metric_syss.columns = ['name', 'lp', 'testset', 'system', metric_name] + list(metric_syss.columns[5:])
sys_scores = sys_scores.merge(metric_syss[['lp','system',metric_name]], on=['lp','system'], how='outer')

# %% [markdown]
# ### Join metric and da scores

# %%
sys_scores_da = da_sys.merge(sys_scores)
sys_scores_da = sys_scores_da[['lp', 'score', 'system', 'BLEU', 'NIST', 'CDER', 'PER', 'TER', 'WER']]
sys_scores_da
# Out:
#         lp  score                           system    BLEU    NIST    CDER  \
# 0    en-cs  0.402     CUNI-DocTransformer-T2T.6751  0.1904  5.1045  0.5042
# 1    en-cs  0.401   CUNI-Transformer-T2T-2018.6457  0.1968  5.2036  0.5042
# 2    en-cs  0.388   CUNI-Transformer-T2T-2019.6851  0.1892  5.0849  0.4977
# 3    en-cs  0.223  CUNI-DocTransformer-Marian.6922  0.1769  4.8610  0.4877
# 4    en-cs  0.206                       uedin.6667  0.1916  5.1417  0.4895
# ..     ...    ...                              ...     ...     ...     ...
# 220  de-fr  0.019                       online-Y.0  0.3641  8.3309  0.5197
# 221  de-fr -0.104                  TartuNLP-c.6897  0.3415  7.9147  0.4967
# 222  de-fr -0.194                       online-A.0  0.3515  7.9717  0.5002
# 223  de-fr -0.240                       online-G.0  0.3412  8.0219  0.4724
# 224  de-fr -0.456                       online-X.0  0.3226  7.6172  0.4598
#
#         PER     TER     WER
# 0    0.6061  0.4697  0.4427
# 1    0.6037  0.4714  0.4452
# 2    0.5971  0.4647  0.4386
# 3    0.5878  0.4513  0.4243
# 4    0.5877  0.4589  0.4323
# ..      ...     ...     ...
# 220  0.6065  0.4936  0.4665
# 221  0.5908  0.4629  0.4348
# 222  0.6134  0.4508  0.4212
# 223  0.5738  0.4308  0.4067
# 224  0.5566  0.4210  0.3970
#
# [225 rows x 9 columns]

# %% [markdown]
# ### Validate correlations

# %%
sys_scores_da.groupby('lp') \
    ['lp'] \
    .count()
# Out:
# lp
# de-cs    11
# de-en    16
# de-fr    11
# en-cs    11
# en-de    22
# en-fi    12
# en-gu    11
# en-kk    11
# en-lt    12
# en-ru    12
# en-zh    12
# fi-en    12
# fr-de    10
# gu-en    11
# kk-en    11
# lt-en    11
# ru-en    14
# zh-en    15
# Name: lp, dtype: int64

# %%
sys_scores_da[sys_scores_da.lp.str.endswith('en')] \
    .groupby('lp') \
    .corr()[::7] \
    .round(3) \
    .T \
    .sort_index()
# Out:
# lp     de-en  fi-en  gu-en  kk-en  lt-en  ru-en  zh-en
#        score  score  score  score  score  score  score
# BLEU   0.849  0.982  0.834  0.946  0.961  0.879  0.899
# CDER   0.890  0.988  0.876  0.967  0.975  0.892  0.917
# NIST   0.813  0.986  0.930  0.942  0.944  0.925  0.921
# PER    0.883  0.991  0.910  0.737  0.947  0.922  0.952
# TER    0.874  0.984  0.890  0.799  0.960  0.917  0.840
# WER    0.863  0.983  0.861  0.793  0.961  0.911  0.820
# score  1.000  1.000  1.000  1.000  1.000  1.000  1.000

# %%
sys_scores_da[sys_scores_da.lp.str.startswith('en')] \
    .groupby('lp') \
    .corr()[::7] \
    .round(3) \
    .T \
    .sort_index()
# Out:
# lp     en-cs  en-de  en-fi  en-gu  en-kk  en-lt  en-ru  en-zh
#        score  score  score  score  score  score  score  score
# BLEU   0.897  0.921  0.969  0.737  0.852  0.989  0.986  0.901
# CDER   0.985  0.973  0.978  0.840  0.927  0.985  0.993  0.905
# NIST   0.896  0.321  0.971  0.786  0.930  0.993  0.988  0.884
# PER    0.976  0.970  0.982  0.839  0.921  0.985  0.981  0.895
# TER    0.980  0.969  0.981  0.865  0.940  0.994  0.995  0.856
# WER    0.982  0.966  0.980  0.861  0.939  0.991  0.994  0.875
# score  1.000  1.000  1.000  1.000  1.000  1.000  1.000  1.000

# %%
sys_scores_da[~sys_scores_da.lp.str.startswith('en') & ~sys_scores_da.lp.str.endswith('en')] \
    .groupby('lp') \
    .corr()[::7] \
    .round(3) \
    .T \
    .sort_index()
# Out:
# lp     de-cs  de-fr  fr-de
#        score  score  score
# BLEU   0.941  0.891  0.864
# CDER   0.864  0.949  0.852
# NIST   0.954  0.916  0.862
# PER    0.875  0.857  0.899
# TER    0.890  0.956  0.895
# WER    0.872  0.956  0.894
# score  1.000  1.000  1.000

# %% [markdown]
# ### WMT19 system-level data (raw)

# %%
lp_df = []

for file in glob.glob('data/newstest2019-humaneval/*-sntlevel-humaneval-newstest2019/analysis/ad-seg-scores-*.csv'):
    lp = file[-9:-4]
    print(lp)
    
    df = pd.read_csv(file, delimiter=' ')
    df['lp'] = [lp] * len(df)
    
    lp_df.append(df)
raw_seg_scores_da = pd.concat(lp_df)
# Out:
# de-cs
# de-fr
# zh-en
# fr-de
# lt-en
# ru-en
# kk-en
# fi-en
# gu-en

# %% [markdown]
# mturk = pd.read_csv('data/newstest2019-humaneval/mturk-sntlevel-humaneval-newstest2019/analysis/ad-good-raw-redup.csv', sep='\t')
# print(len(mturk))
# turkle = pd.read_csv('data/newstest2019-humaneval/turkle-sntlevel-humaneval-newstest2019/analysis/ad-good-raw-redup.csv', sep='\t')
# print(len(turkle))
# raw_seg_scores_da = pd.concat([mturk, turkle])
# print(len(raw_seg_scores_da))

# %%
raw_seg_scores_da.head(1)
# Out:
#           SYS   SID  RAW.SCR     Z.SCR  N  Unnamed: 5     lp
# 0  online-Y.0  1478     50.0 -0.444243  1         NaN  de-cs

# %%
raw_sys_scores_da = raw_seg_scores_da.groupby(['lp', 'SYS'], as_index=False).mean()

raw_sys_scores_da.columns = ['lp', 'system', 'sid', 'raw_score', 'score', 'N', '5']
raw_sys_scores_da = raw_sys_scores_da[['lp', 'system', 'raw_score', 'score']]

# %%
print(len(sys_scores_da))
sys_scores_da = sys_scores_da.merge(raw_sys_scores_da[['lp','system','raw_score']])
print(len(sys_scores_da))
sys_scores_da[['lp','raw_score', 'score']].groupby('lp').corr('pearson')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-03f672abfcdf> in <module>
# ----> 1 print(len(sys_scores_da))
#       2 sys_scores_da = sys_scores_da.merge(raw_sys_scores_da[['lp','system','raw_score']])
#       3 print(len(sys_scores_da))
#       4 sys_scores_da[['lp','raw_score', 'score']].groupby('lp').corr('pearson')
#
# NameError: name 'sys_scores_da' is not defined

# %%
# we only have 81 systems left because most of the systems were
# labelled with DA + document context. The remaining 81 systems
# are evaluated with vanilla DA.

# %% [markdown]
# ### WMT system-level (src, ref, out)

# %%
raw_seg_scores_da.head(1)
# Out:
#           SYS   SID  RAW.SCR     Z.SCR  N  Unnamed: 5     lp
# 0  online-Y.0  1478     50.0 -0.444243  1         NaN  de-cs

# %%
raw_seg_scores_da = raw_seg_scores_da[['SYS','SID','RAW.SCR','Z.SCR','N','lp']]
raw_seg_scores_da.columns = ['system', 'sid', 'raw_score', 'score', 'N', 'lp']

raw_seg_scores_da['system'] = raw_seg_scores_da['system'].apply(lambda x: x[:-6] if x.endswith('.zh-en') else x)

# %%
raw_seg_scores_da.head(1)
# Out:
#        system   sid  raw_score     score  N     lp
# 0  online-Y.0  1478       50.0 -0.444243  1  de-cs

# %%
# srcs and refs
srcs, refs, lps, sids = [], [], [], []
for lp in raw_seg_scores_da.lp.unique():
    fr, to = lp[:2], lp[3:]
    print(lp)
    
    refs_ = list(open('data/wmt19-submitted-data/txt/references/newstest2019-%s%s-ref.%s' % (fr, to, to)))
    srcs_ = list(open('data/wmt19-submitted-data/txt/sources/newstest2019-%s%s-src.%s' % (fr, to, fr)))
    sids_ = list(range(1, len(refs_)+1))
    refs.extend(refs_)
    srcs.extend(srcs_)
    sids.extend(sids_)
    
    assert(len(refs_) == len(srcs_))
    lps.extend([lp]*len(refs_))
    
src_ref_df = pd.DataFrame({'reference' : refs, 'source':srcs, 'lp': lps, 'sid': sids})
print(len(src_ref_df), len(raw_seg_scores_da))
raw_seg_scores_da = raw_seg_scores_da.merge(src_ref_df, on=['lp','sid'], how='inner')
print(len(raw_seg_scores_da))
# Out:
# de-cs
# de-fr
# zh-en
# fr-de
# lt-en
# ru-en
# kk-en
# fi-en
# gu-en
# 14411 129126
# 129126

# %%
# outs
lps, outs, sids, syss = [], [], [], []
for file in glob.glob('data/wmt19-submitted-data/txt/system-outputs/newstest2019/*/*'):
    lp = file.split('.')[-1]
    system = '.'.join(file.split('.')[1:-1])
    print(lp, system)
    
    if 'Unsupervised.' in system:
        system = system[:13] + system[-4:]
    elif '_' in system and not any(['NEU_KingSoft' in system, 'Kyoto_University' in system, 'lingua_custodia_primary' in system]):
        system = system.replace('_', '-')
    
    outs_ = list(open(file, 'rt'))
    sids_ = list(range(1, len(outs_)+1))
    lps_ = len(outs_) * [lp]
    syss_ = len(outs_) * [system]
    
    outs.extend(outs_)
    sids.extend(sids_)
    lps.extend(lps_)
    syss.extend(syss_)

out_df = pd.DataFrame({'lp': lps, 'output':outs, 'sid': sids, 'system': syss})
print(len(out_df), len(raw_seg_scores_da))
raw_seg_scores_da = raw_seg_scores_da.merge(out_df, on=['lp','sid', 'system'], how='left')
print(len(raw_seg_scores_da))
# Out:
# cs-de online-B.0
# cs-de Unsupervised.cs-de.6979
# cs-de online-G.0
# cs-de NEU_KingSoft.6783
# cs-de online-A.0
# cs-de online-Y.0
# cs-de NICT.6948
# en-gu online-B.0
# en-gu MSRA.CrossBERT.6991
# en-gu CUNI-T2T-transfer-engu.6466
# en-gu GTCOM-Primary.6970
# en-gu UdS-DFKI.6866
# en-gu online-G.0
# en-gu Ju_Saarland_clean_num_135_bpe.6617
# en-gu UEDIN.6849
# en-gu NICT.6604
# en-gu online-X.0
# en-gu IITP-MT.6827
# kk-en rug_kken_morfessor.6677
# kk-en DBMS-KU_KKEN.6726
# kk-en online-G.0
# kk-en NICT.6770
# kk-en online-B.0
# kk-en NEU.6753
# kk-en talp_upc_2019_kken.6657
# kk-en CUNI-T2T-transfer-kken.6436
# kk-en NRC-CNRC.6895
# kk-en UMD.6736
# kk-en Frank_s_MT.6127
# en-lt MSRA.MASS.6931
# en-lt tilde-nc-nmt.6696
# en-lt eTranslation.6836
# en-lt TartuNLP-c.6510
# en-lt NEU.6760
# en-lt online-X.0
# en-lt online-A.0
# en-lt GTCOM-Primary.7001
# en-lt online-G.0
# en-lt MSRA.MASS.6954
# en-lt tilde-c-nmt.6695
# en-lt online-B.0
# gu-en NICT.6603
# gu-en GTCOM-Primary.6969
# gu-en UdS-DFKI.6861
# gu-en online-B.0
# gu-en IITP-MT.6824
# gu-en IIITH-MT.6688
# gu-en NEU.6756
# gu-en Ju_Saarland.6525
# gu-en UEDIN.6534
# gu-en online-G.0
# gu-en CUNI-T2T-transfer-guen.6431
# gu-en aylien_mt_gu-en_multilingual.6826
# en-cs online-G.0
# en-cs TartuNLP-c.6633
# en-cs CUNI-Transformer-T2T-2019.6851
# en-cs online-B.0
# en-cs CUNI-Transformer-T2T-2018.6457
# en-cs uedin.6667
# en-cs online-X.0
# en-cs CUNI-DocTransformer-T2T.6751
# en-cs online-Y.0
# en-cs online-A.0
# en-cs CUNI-DocTransformer-Marian.6922
# ru-en online-G.0
# ru-en Facebook_FAIR.6937
# ru-en rerank-re.6540
# ru-en online-B.0
# ru-en afrl-ewc.6659
# ru-en TartuNLP-u.6650
# ru-en NICT.6561
# ru-en online-X.0
# ru-en eTranslation.6598
# ru-en MSRA.SCA.6976
# ru-en NEU.6803
# ru-en online-A.0
# ru-en afrl-syscomb19.6782
# ru-en online-Y.0
# en-de MSRA.MADL.6926
# en-de online-X.0
# en-de Microsoft-WMT19-document-level.6808
# en-de Microsoft-WMT19-sentence_document.6974
# en-de JHU.6819
# en-de UdS-DFKI.6871
# en-de Microsoft-WMT19-sentence-level.6785
# en-de online-A.0
# en-de eTranslation.6823
# en-de en_de_task.6790
# en-de online-Y.0
# en-de Facebook_FAIR.6862
# en-de dfki-nmt.6479
# en-de TartuNLP-c.6508
# en-de Helsinki-NLP.6820
# en-de MLLP-UPV.6651
# en-de online-G.0
# en-de online-B.0
# en-de lmu-ctx-tf-single-en-de.6981
# en-de NEU.6763
# en-de PROMT_NMT_EN-DE.6674
# en-de UCAM.6731
# en-ru TartuNLP-u.6645
# en-ru NICT.6563
# en-ru online-A.0
# en-ru online-Y.0
# en-ru online-X.0
# en-ru PROMT_NMT_EN-RU.6989
# en-ru online-B.0
# en-ru USTC-MCC.6795
# en-ru Facebook_FAIR.6724
# en-ru rerank-er.6572
# en-ru NEU.6773
# en-ru online-G.0
# fr-de online-Y.0
# fr-de online-A.0
# fr-de MSRA.MADL.6893
# fr-de TartuNLP-c.6514
# fr-de online-X.0
# fr-de MLLP-UPV.6654
# fr-de online-B.0
# fr-de eTranslation.6262
# fr-de LIUM.6720
# fr-de online-G.0
# en-fi online-B.0
# en-fi MSRA.NAO.6985
# en-fi online-G.0
# en-fi GTCOM-Primary.6917
# en-fi TartuNLP-c.6509
# en-fi Helsinki_NLP.6860
# en-fi NICT.6359
# en-fi online-Y.0
# en-fi online-A.0
# en-fi online-X.0
# en-fi apertium-fin-eng-unconstrained-en-fi.6448
# en-fi Helsinki_NLP__rule-based_.6636
# de-cs Unsupervised.de-cs.6935
# de-cs online-G.0
# de-cs CAiRE.6949
# de-cs online-B.0
# de-cs NICT.6938
# de-cs NEU_KingSoft.6766
# de-cs CUNI-Unsupervised-NER-post.6934
# de-cs Unsupervised.de-cs.6929
# de-cs lmu-unsup-nmt-de-cs.6845
# de-cs online-Y.0
# de-cs online-A.0
# zh-en Apprentice-c.6706
# zh-en online-A.0
# zh-en online-Y.0
# zh-en KSAI-system.6927
# zh-en Baidu-system.6940
# zh-en MSRA.MASS.6996
# zh-en NEU.6832
# zh-en BTRANS.6825
# zh-en UEDIN.6530
# zh-en online-X.0
# zh-en NICT.6814
# zh-en BTRANS-ensemble.6992
# zh-en online-B.0
# zh-en MSRA.MASS.6942
# zh-en online-G.0
# en-kk DBMS-KU_ENKK.6730
# en-kk CUNI-T2T-transfer-enkk.6554
# en-kk talp_upc_2019_enkk.6355
# en-kk NEU.6755
# en-kk NICT.6550
# en-kk UAlacant_-_NMT.6718
# en-kk MSRA.CrossBERT.6874
# en-kk UAlacant_-_NMT+RBMT.6722
# en-kk online-B.0
# en-kk online-G.0
# en-kk rug_enkk_bpe.6804
# fi-en GTCOM-Primary.6946
# fi-en apertium-fin-eng-unconstrained-fien.6449
# fi-en online-B.0
# fi-en online-G.0
# fi-en TartuNLP-c.6905
# fi-en Helsinki_NLP.6889
# fi-en online-Y.0
# fi-en USYD.6995
# fi-en online-A.0
# fi-en MSRA.NAO.6983
# fi-en online-X.0
# fi-en parfda.6526
# de-fr online-G.0
# de-fr TartuNLP-c.6897
# de-fr online-B.0
# de-fr LIUM.6719
# de-fr MSRA.MADL.6888
# de-fr Kyoto_University_T2T.6679
# de-fr MLLP-UPV.6647
# de-fr online-X.0
# de-fr lingua_custodia_primary.6690
# de-fr online-A.0
# de-fr online-Y.0
# lt-en online-B.0
# lt-en tilde-nc-nmt.6881
# lt-en TartuNLP-c.6908
# lt-en MSRA.MASS.6945
# lt-en GTCOM-Primary.6998
# lt-en online-G.0
# lt-en JUMT.6616
# lt-en NEU.6759
# lt-en online-A.0
# lt-en online-X.0
# lt-en tilde-c-nmt.6876
# de-en RWTH_Aachen_System.6818
# de-en Facebook_FAIR.6750
# de-en UCAM.6461
# de-en MSRA.MADL.6910
# de-en online-G.0
# de-en online-B.0
# de-en NEU.6801
# de-en dfki-nmt.6478
# de-en online-X.0
# de-en uedin.6749
# de-en PROMT_NMT_DE-EN.6683
# de-en TartuNLP-c.6502
# de-en MLLP-UPV.6899
# de-en JHU.6809
# de-en online-A.0
# de-en online-Y.0
# en-zh NEU.6830
# en-zh UEDIN.6158
# en-zh NICT.6817
# en-zh online-B.0
# en-zh KSAI-system.6982
# en-zh online-G.0
# en-zh Baidu-system.6932
# en-zh online-Y.0
# en-zh online-A.0
# en-zh BTRANS.6821
# en-zh xzl-nmt.6847
# en-zh online-X.0
# 391536 129126
# 129126

# %%
raw_seg_scores_da.lp.value_counts()
# Out:
# ru-en    25310
# fi-en    20420
# zh-en    20199
# de-cs    16900
# gu-en    11996
# kk-en    11805
# lt-en    11796
# de-fr     6700
# fr-de     4000
# Name: lp, dtype: int64

# %% [markdown]
# ### Pickle

# %%
pickle.dump(raw_seg_scores_da, open('data/pickles/wmt19-sys_level-all.pkl', 'wb'))
#pickle.dump(sys_scores_da, open('data/pickles/wmt19-sys_level-agg.pkl', 'wb'))
